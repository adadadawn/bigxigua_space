# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %rm -r /content/sample_data

# %%
# %cp -r /content/drive/MyDrive/SPACE /content

# %%
print('\n> Cloning the repo')
# !git clone https://github.com/choyingw/SynergyNet

# %cd SynergyNet
# %cd Sim3DR
# !sh ./build_sim3dr.sh

# %cd ../FaceBoxes
# !sh ./build_cpu_nms.sh
# %cd ..

# !gdown --id 1SQsMhvAmpD1O8Hm0yEGom0C0rXtA0qs8
# !unzip -n 3dmm_data

# !gdown --id 1BVHbiLTfX6iTeJcNbh-jgHjWDoemfrzG

# %pip install -e .
# !mv best.pth.tar  ./pretrained
# !mv 3dmm_data.zip ./pretrained/
# Out:
# > Cloning the repo
# Cloning into 'SynergyNet'...
# remote: Enumerating objects: 303, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 303 (delta 30), reused 46 (delta 21), pack-reused 230
# Receiving objects: 100% (303/303), 40.10 MiB | 22.39 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# /content/SynergyNet
# /content/SynergyNet/Sim3DR
# running build_ext
# cythoning lib/rasterize.pyx to lib/rasterize.cpp
# /usr/local/lib/python3.9/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/SynergyNet/Sim3DR/lib/rasterize.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'Sim3DR_Cython' extension
# creating build
# creating build/temp.linux-x86_64-3.9
# creating build/temp.linux-x86_64-3.9/lib
# ...

# %%
# %cp -rf /content/SynergyNet /content/SPACE/SynergyNet

# %%
from synergy3DMM import SynergyNet
# Out:
# /content/SynergyNet

# %%
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %run /content/SPACE/mcff.py
# Out:
# audio_feature_new.shpae (601, 1, 40)

# %%
# %run /content/SPACE/landmarks2.py
# Out:
# loading weights from  /content/SynergyNet/pretrained/best.pth.tar
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /content/SPACE/landmarks2.py in <module>
#      79   # print('translated_3_lmk.shape',x[2].shape)
#      80 if __name__=='__main__':
# ---> 81   main()
#      82
#      83
#
# /content/SPACE/landmarks2.py in main()
#      59
#      60   x= get_landmarks(model,image)
# ---> 61   xy_translated_mesh = x[1][[1,0], :]
#      62   # print('yx_translated_mesh.shape',xy_translated_mesh.shape)
#      63   # 绘制图像
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# $$(N, C_{out}, L_{out}) = \left\lfloor\frac{(N, C_{in}, L_{in} + 2\times\text{padding} - \text{dilation}\times (\text{kernel_size}-1) - 1)}{\text{stride}} + 1\right\rfloor$$

# %%
# %run /content/SPACE/test.py
# Out:
# mcff.shape torch.Size([601, 1024, 1])
# mfcc.shape torch.Size([601, 1, 1024])
# loading weights from  /content/SynergyNet/pretrained/best.pth.tar
# lmk_old.shpae (3, 68)
# lmk_old torch.Size([3, 68])
# lmk_net.shape torch.Size([68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# ...

# %%
# %run /content/SPACE/mcff.py
# Out:
# audio_feature_new.shpae (601, 1, 40)

# %%
# %run /content/SPACE/landmarks2.py
# Out:
# loading weights from  /content/SynergyNet/pretrained/best.pth.tar
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /content/SPACE/landmarks2.py in <module>
#      79   # print('translated_3_lmk.shape',x[2].shape)
#      80 if __name__=='__main__':
# ---> 81   main()
#      82
#      83
#
# /content/SPACE/landmarks2.py in main()
#      59
#      60   x= get_landmarks(model,image)
# ---> 61   xy_translated_mesh = x[1][[1,0], :]
#      62   # print('yx_translated_mesh.shape',xy_translated_mesh.shape)
#      63   # 绘制图像
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# %run /content/SPACE/test.py
# Out:
# mcff.shape torch.Size([601, 1024, 1])
# mfcc.shape torch.Size([601, 1, 1024])
# loading weights from  /content/SynergyNet/pretrained/best.pth.tar
# lmk_old.shpae (3, 68)
# lmk_old torch.Size([3, 68])
# lmk_net.shape torch.Size([68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# torch.Size([1, 68, 1027]) torch.Size([1, 68, 3])
# 1 torch.Size([1, 1024])
# ...
